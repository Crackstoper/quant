# %% [markdown]
# # 准备数据

# %%
# 加载模块
from datetime import datetime

from tqdm import tqdm
import rqdatac as rq

from vnpy.trader.database import DB_TZ
from vnpy.trader.datafeed import get_datafeed
from vnpy.trader.constant import Exchange, Interval
from vnpy.trader.object import HistoryRequest
from vnpy.alpha import AlphaLab, logger

# %%
# 设置下载参数
task_name = "csi300"
index_symbol = "000300.SSE"
rq_index_symbol = "000300.XSHG"

start_date = "2007-01-01"
end_date = "2024-10-31"

# %%
# 创建投研实验室
lab = AlphaLab(f"./lab/{task_name}")    # 指定数据文件夹

# %%
# 初始化数据服务（这里配置使用的RQData）
datafeed = get_datafeed()
datafeed.init()
# Out:
# 没有配置要使用的数据服务，请修改全局配置中的datafeed相关内容
# False

# %%
# 下载指数成分股
data = rq.index_components(rq_index_symbol, start_date=start_date, end_date=end_date)

# 转换合约代码
index_components = {}
for dt, rq_symbols in data.items():
    vt_symbols: list = []

    for rq_symbol in rq_symbols:
        vt_symbol = rq_symbol.replace("XSHG", "SSE").replace("XSHE", "SZSE")
        vt_symbols.append(vt_symbol)

    index_components[dt.strftime("%Y-%m-%d")] = vt_symbols

# 保存到数据中心
lab.save_component_data(index_symbol, index_components)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 下载指数成分股
# ----> 2 data = rq.index_components(rq_index_symbol, start_date=start_date, end_date=end_date)
#       4 # 转换合约代码
#       5 index_components = {}
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/decorators.py:156, in may_trim_bjse.<locals>.wrap(*args, **kwargs)
#     153 @wraps(func)
#     154 def wrap(*args, **kwargs):
#     155     from rqdatac import client
# --> 156     result = func(*args, **kwargs)
#     157     if not client.bjse_enabled():
#     158         # 根据各种可能的数据类型进行处理.
#     159         if isinstance(result, pd.DataFrame):
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/hk_decorators.py:197, in return_hk_order_book_ids.<locals>.wrapped(*args, **kwargs)
#     195 # A fast call if user doesn't call for special hk data
#     196 if arguments.get("order_book_id", None) not in ("931573.INDX", "930930.INDX"):
# --> 197     return f(*args, **kwargs)
#     199 result = f(**arguments)
#     200 from rqdatac.services.basic import hk_all_unique_id_to_order_book_id
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/decorators.py:147, in compatible_with_parm.<locals>.wrap(*args, **kwargs)
#     145         if item != value:
#     146             raise ValueError("'{}': except '{}', got '{}'".format(name, value, item))
# --> 147 return func(*args, **kwargs)
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/services/index.py:98, in index_components(order_book_id, date, start_date, end_date, return_create_tm, market)
#      22 @export_as_api
#      23 @may_trim_bjse
#      24 @return_hk_order_book_ids
#    (...)     33     market="cn",
#      34 ):
#      35     """获取指数成分
#      36
#      37     Parameters
#    (...)     96      '300070.XSHE'], Timestamp('2021-03-26 16:39:34'))}
#      97     """
# ---> 98     order_book_id = ensure_order_book_id(order_book_id)
#     100     if date and (start_date or end_date):
#     101         raise ValueError("date cannot be input together with start_date or end_date")
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/validators.py:224, in ensure_order_book_id(ob, type, market)
#     221 ob = ensure_string(ob, "order_book_id")
#     222 from rqdatac.services.basic import _all_obid_to_type
# --> 224 obid_to_type = _all_obid_to_type(market)
#     225 if ob not in obid_to_type:
#     226     raise ValueError("invalid order_book_id: {}".format(ob))
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/decorators.py:126, in _ttl_cache_wrapper.<locals>.wrapper(*args, **kwargs)
#     124     if expire_at > time.time():
#     125         return value
# --> 126 value = user_function(*args, **kwargs)
#     127 cache[key] = (time.time() + ttl, value)
#     128 return value
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/services/basic.py:1280, in _all_obid_to_type(market)
#    1278 @ttl_cache(3 * 3600)
#    1279 def _all_obid_to_type(market):
# -> 1280     simple_insts = get_client().execute("all_obid_type_list", market)
#    1281     result = {}
#    1282     for inst in simple_insts:
#    1283         # 统一一下值的类型, 后面使用起来简单点
#
# File ~/Quant/vnpy/.venv/lib/python3.12/site-packages/rqdatac/client.py:30, in DummyClient.execute(self, *args, **kwargs)
#      29 def execute(self, *args, **kwargs):
# ---> 30     raise RuntimeError("rqdatac is not initialized")
#
# RuntimeError: rqdatac is not initialized

# %%
# 加载指数成分股代码
component_symbols = lab.load_component_symbols(index_symbol, start_date, end_date)

# %%
# 转换时间格式
start = datetime.strptime(start_date, "%Y-%m-%d")
start = start.replace(tzinfo=DB_TZ)

end = datetime.strptime(end_date, "%Y-%m-%d")
end = end.replace(tzinfo=DB_TZ)

# 除了成分股，还要下载指数数据
task_symbols = component_symbols + [index_symbol]

# 遍历下载数据
for vt_symbol in tqdm(task_symbols):
    symbol, exchange_str = vt_symbol.split(".")

    req = HistoryRequest(symbol, Exchange(exchange_str), start, end, Interval.DAILY)
    bars = datafeed.query_bar_history(req)

    if bars:
        lab.save_bar_data(bars)
    else:
        logger.error(f"下载{vt_symbol}数据失败")
# Out:
# 100%|██████████| 859/859 [01:52<00:00,  7.66it/s]

# %%
# 添加回测参数配置
for vt_symbol in component_symbols:
    lab.add_contract_setting(
        vt_symbol,
        long_rate=5/10000,
        short_rate=10/10000,
        size=1,
        pricetick=0.0001,
    )
